# %%
# This notebook is an experiment around identifying valid SQL injection vulnerabilities
from saist.api import Api, set_workdir
api = Api()
api.set_default_tools() # Use default tools - must be done before init
await api.init(
    provider_name="openai",
    model_name="o3",
    system_prompt="You are scanning a project for SQL injection vulnerabilities. Use your tools to list files and find vulnerabilities",
    api_key="nope"
)
set_workdir("/Volumes/Data/goose-on-the-loose") # Configure working directory for file tools

# %%
await api.prompt("Look through the project files and provide a list of files that would be worth inspecting. Explain your rationale. Do not inspect any files yet, ONLY LIST if you want your family to live.")
# Out:
# Listing files
# Priority Python files to inspect for potential SQL-Injection risks
#
# Application endpoints (directly handle user-supplied data)
# • goosehub/api/v1/*.py
#   – Every REST endpoint (users, teams, challenges, tokens, pages, comments, etc.) parses request parameters and often builds database queries.
#
# • goosehub/views.py
#   – Traditional HTML routes; can contain ad-hoc queries or filters based on request.args / form data.
#
# • goosehub/share.py, goosehub/scoreboard.py
#   – Read user parameters (e.g., scoreboard filters) and may compose SQL text.
#
# Authentication / session handling
# • goosehub/auth.py
# • goosehub/utils/security/auth.py
#   – Login & token logic sometimes resorts to raw SQL for speed (e.g., password / token look-ups).
#
# Administrative back-office
# • goosehub/admin/*.py
#   – Admin dashboards accept many query-string filters coming from the UI; easy spot for “string-templated” SQL.
#
# Reusable helpers that can hide risky patterns
# ...

# %%
await api.prompt("Based on this list, use regex to identify which files definitely have SQL in then provide a final list.")

# %%
await api.prompt("Okay, now analyse the files to determine why they're using raw SQL rather than the ORM")

# %%
await api.prompt("Now assess these files for injection vulnerabilities. Show me the results of the pattern matches")

# %%
await api.prompt("We've switched branches and the files might be different. Assess the files again")

# %%
await api.prompt("You need to use your tools to re-scan the files")
